# %% [markdown]
# <a href="https://colab.research.google.com/github/chejarlarajamouli/DAA-LAB/blob/main/AI_PRATICAL_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRATICAL-1**

# %% [markdown]
# **Spam mail detection-1**

# %%
message = input("Enter a message: ")

spam_words = ["win", "free", "lottery", "prize", "offer"]

message = message.lower()

if any(word in message for word in spam_words):
    print("Spam Message")
else:
    print("Not Spam Message")
# Out:
# Enter a message: win
# Spam Message

# %% [markdown]
# **2 Cleaning robot**

# %%
print("Hello! I am Python.")
print("Today we will build a cleaning robot together. 🤖")
print(2 + 3, "is the answer to 2 + 3")


room = ["D", "C", "D", "D", "C"]

def show_room(room):
    picture = ""
    for spot in room:
        if spot == "D":
            picture += "💩 "
        else:
            picture += "✨ "
    print(picture)

print("Our room right now:")
show_room(room)

def clean_spot(spot):
    if spot == "D":
        return "C"
    else:
        return "C"


result = clean_spot("D")
print("The robot looked at a dirty spot 💩 and made it:", result,
      "(C means clean ✨)")

print("BEFORE - the dirty room:")
show_room(room)


for i in range(len(room)):
    room[i] = clean_spot(room[i])
    print("After cleaning spot number", i + 1, ":")
    show_room(room)

print()
print("AFTER - all done! ✨🤖")
# Out:
# Hello! I am Python.
# Today we will build a cleaning robot together. 🤖
# 5 is the answer to 2 + 3
# Our room right now:
# 💩 ✨ 💩 💩 ✨
# The robot looked at a dirty spot 💩 and made it: C (C means clean ✨)
# BEFORE - the dirty room:
# 💩 ✨ 💩 💩 ✨
# After cleaning spot number 1 :
# ✨ ✨ 💩 💩 ✨
# After cleaning spot number 2 :
# ✨ ✨ 💩 💩 ✨
# After cleaning spot number 3 :
# ✨ ✨ ✨ 💩 ✨
# After cleaning spot number 4 :
# ✨ ✨ ✨ ✨ ✨
# After cleaning spot number 5 :
# ✨ ✨ ✨ ✨ ✨
#
# AFTER - all done! ✨🤖

# %% [markdown]
# **3 CHAT BOX**

# %%
def chatbox():
    print("Hello! iam chatbox.")
    while True:
        user_input = input("You: ")
        if user_input == "what is your name":
            print("Chatbox: RAJAMOULI")
            break
        else:
            print("Chatbox:you said",user_input,"next")

chatbox()
# Out:
# Hello! iam chatbox.
# You: RAJAMOULI
# Chatbox:you said RAJAMOULI next
# You: HI
# Chatbox:you said HI next
# You: BYY
# Chatbox:you said BYY next
# You: what is your name
# Chatbox: RAJAMOULI
