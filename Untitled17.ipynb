# %% [markdown]
# <a href="https://colab.research.google.com/github/chejarlarajamouli/DAA-LAB/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
{rr, key):\n",
        "    for i in range(len(arr)):\n",
        "        if arr[i] == key:\n",
        "            return i\n",
        "    return -1\n",
        "\n",
        "\n",
        "# Binary Search Function\n",
        "def binary_search(arr, key):\n",
        "    low = 0\n",
        "    high = len(arr) - 1\n",
        "\n",
        "    while low <= high:\n",
        "        mid = low + (high - low) // 2\n",
        "\n",
        "        if arr[mid] == key:\n",
        "            return mid\n",
        "        elif arr[mid] < key:\n",
        "            low = mid + 1\n",
        "        else:\n",
        "            high = mid - 1\n",
        "\n",
        "    return -1\n",
        "\n",
        "\n",
        "# Main Program\n",
        "n = 100000\n",
        "arr = list(range(1, n + 1))  # Creating a sorted array\n",
        "\n",
        "key = int(input(\"Enter element to search: \"))\n",
        "\n",
        "# Linear Search Timing\n",
        "start = time.perf_counter()\n",
        "index = linear_search(arr, key)\n",
        "stop = time.perf_counter()\n",
        "\n",
        "print(\"\\nLinear Search\")\n",
        "if index != -1:\n",
        "    print(\"Element found at index\", index)\n",
        "else:\n",
        "    print(\"Element not found\")\n",
        "\n",
        "print(\"Time Taken:\", (stop - start) * 1_000_000, \"microseconds\")\n",
        "\n",
        "# Binary Search Timing\n",
        "start = time.perf_counter()\n",
        "index = binary_search(arr, key)\n",
        "stop = time.perf_counter()\n",
        "\n",
        "print(\"\\nBinary Search\")\n",
        "if index != -1:\n",
        "    print(\"Element found at index\", index)\n",
        "else:\n",
        "    print(\"Element not found\")\n",
        "\n",
        "print(\"Time Taken:\", (stop - start) * 1_000_000, \"microseconds\")"
      ]
    }
  ]
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_525/4024415477.py in <cell line: 0>()
#      17     {
#      18       "cell_type": "code",
# ---> 19       "execution_count": null,
#      20       "metadata": {
#      21         "id": "BwUxdmZ4E8Tb"
#
# NameError: name 'null' is not defined

# %%
import time

# Iterative Factorial Function
def factorial_iterative(n):
    result = 1

    for i in range(1, n + 1):
        result *= i

    return result


# User Input
n = int(input("Enter a non-negative integer: "))

if n < 0:
    print("Invalid input! Please enter a non-negative integer.")
else:
    # Start timer
    start_time = time.perf_counter_ns()

    # Calculate factorial
    result = factorial_iterative(n)

    # Stop timer
    end_time = time.perf_counter_ns()

    # Calculate execution time
    execution_time = end_time - start_time

    # Display result
    print(f"\n--- Iterative Factorial for {n}! ---")
    print("Factorial Result :", result)
    print("Execution Time   :", execution_time, "ns")

    # Time and Space Complexity
    print("\nTime Complexity:")
    print("O(n)")

    print("Space Complexity:")
    print("O(1)")
# Out:
# Enter a non-negative integer: 5
#
# --- Iterative Factorial for 5! ---
# Factorial Result : 120
# Execution Time   : 5324 ns
#
# Time Complexity:
# O(n)
# Space Complexity:
# O(1)

# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": [],
      "authorship_tag": "ABX9TyOL0YEi4BfmpzIhfW4PClyR",
      "include_colab_link": true
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {
        "id": "view-in-github",
        "colab_type": "text"
      },
      "source": [
        "<a href=\"https://colab.research.google.com/github/charath567/DAA-LAB/blob/main/DAA_PRATICAL_4.ipynb\" target=\"_parent\"><img src=\"https://colab.research.google.com/assets/colab-badge.svg\" alt=\"Open In Colab\"/></a>"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": 1,
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "a3X2DbEz_FtI",
        "outputId": "9fa9d0dc-13c9-4ee7-dc1c-cda7fcb8ae37"
      },
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Enter a non-negative integer: 5\n",
            "\n",
            "--- Iterative Factorial for 5! ---\n",
            "Factorial Result : 120\n",
            "Execution Time   : 4370 ns\n",
            "\n",
            "Time Complexity:\n",
            "O(n)\n",
            "Space Complexity:\n",
            "O(1)\n"
          ]
        }
      ],
      "source": [
        "import time\n",
        "\n",
        "# Iterative Factorial Function\n",
        "def factorial_iterative(n):\n",
        "    result = 1\n",
        "\n",
        "    for i in range(1, n + 1):\n",
        "        result *= i\n",
        "\n",
        "    return result\n",
        "\n",
        "\n",
        "# User Input\n",
        "n = int(input(\"Enter a non-negative integer: \"))\n",
        "\n",
        "if n < 0:\n",
        "    print(\"Invalid input! Please enter a non-negative integer.\")\n",
        "else:\n",
        "    # Start timer\n",
        "    start_time = time.perf_counter_ns()\n",
        "\n",
        "    # Calculate factorial\n",
        "    result = factorial_iterative(n)\n",
        "\n",
        "    # Stop timer\n",
        "    end_time = time.perf_counter_ns()\n",
        "\n",
        "    # Calculate execution time\n",
        "    execution_time = end_time - start_time\n",
        "\n",
        "    # Display result\n",
        "    print(f\"\\n--- Iterative Factorial for {n}! ---\")\n",
        "    print(\"Factorial Result :\", result)\n",
        "    print(\"Execution Time   :\", execution_time, \"ns\")\n",
        "\n",
        "    # Time and Space Complexity\n",
        "    print(\"\\nTime Complexity:\")\n",
        "    print(\"O(n)\")\n",
        "\n",
        "    print(\"Space Complexity:\")\n",
        "    print(\"O(1)\")"
      ]
    }
  ]
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_525/838797803.py in <cell line: 0>()
#       6       "provenance": [],
#       7       "authorship_tag": "ABX9TyOL0YEi4BfmpzIhfW4PClyR",
# ----> 8       "include_colab_link": true
#       9     },
#      10     "kernelspec": {
#
# NameError: name 'true' is not defined
